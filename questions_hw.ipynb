# %% [markdown]
# <a href="https://colab.research.google.com/github/Triwka/python_homework/blob/main/questions_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import numpy as np 
import pandas as pd

#импортируем библиотеку datetime для работы с датами 
import datetime as dt
from datetime import datetime, date

#Задаем некоторые опции библиотеки pandas, которые настраивают вывод 
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)
pd.set_option('display.width', None)

#импортируем библиотеки matplotlib и seaborn для построения графиков
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
url = 'https://drive.google.com/file/d/1He5GI5_Gd8uXYfeETLBISQ5BszX0o4pU/view?usp=sharing'
url = 'https://drive.google.com/uc?id=' + url.split('/')[-2]
data = pd.read_csv(url,names=['index','gender', 'age', 'hypertension', 'heart_disease',
       'ever_married', 'work_type', 'Residence_type', 'avg_glucose_level',
       'bmi', 'smoking_status', 'stroke'])
data = data.drop('index',axis=1)

# %% [markdown]
# ## Как удалить строки с индексами 0 и 1 из датафрейма одним кодом?

# %%
data
# Out:
#       gender   age  hypertension  heart_disease  ever_married      work_type  \
# 0     gender   age  hypertension  heart_disease  ever_married      work_type
# 1     gender   age  hypertension  heart_disease  ever_married      work_type
# 2       Male  67.0           0.0            1.0           Yes        Private
# 3     Female  61.0           0.0            0.0           Yes  Self-employed
# 4       Male  80.0           0.0            1.0           Yes        Private
# ...      ...   ...           ...            ...           ...            ...
# 5107  Female  80.0           1.0            0.0           Yes        Private
# 5108  Female  81.0           0.0            0.0           Yes  Self-employed
# 5109  Female  35.0           0.0            0.0           Yes  Self-employed
# 5110    Male  51.0           0.0            0.0           Yes        Private
# 5111  Female  44.0           0.0            0.0           Yes       Govt_job
#
# ...

# %%
data.work_type.describe()
# Out:
# count        4777
# unique          6
# top       Private
# freq         2727
# Name: work_type, dtype: object

# %% [markdown]
# ## Как заполнить половину строк одним значением, а половину строк другим?

# %%
data[data.Residence_type.isna()]
# Out:
#       gender   age hypertension heart_disease ever_married      work_type  \
# 4       Male  80.0          0.0           1.0          Yes        Private
# 16    Female  79.0          0.0           NaN          Yes        Private
# 17    Female  50.0          1.0           0.0          Yes  Self-employed
# 20    Female  60.0          0.0           0.0           No        Private
# 21      Male  57.0          0.0           1.0           No       Govt_job
# ...      ...   ...          ...           ...          ...            ...
# 5090  Female  64.0          1.0           0.0          Yes  Self-employed
# 5091  Female  0.72          0.0           NaN           No       children
# 5094    Male  76.0          0.0           0.0          Yes       Govt_job
# 5098    Male   NaN          0.0           0.0          Yes       Govt_job
# 5111  Female  44.0          0.0           0.0          Yes       Govt_job
#
#      Residence_type avg_glucose_level   bmi smoking_status stroke
# ...

# %%
data.Residence_type.value_counts()
# Out:
# Urban             2171
# Rural             2135
# Residence_type       2
# Name: Residence_type, dtype: int64

# %% [markdown]
# ## Как подать модели сбалансированный по классам датафрейм?

# %%
data.stroke.value_counts()
# Out:
# 0         4861
# 1          249
# stroke       2
# Name: stroke, dtype: int64
